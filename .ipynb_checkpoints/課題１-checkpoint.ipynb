# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# (1)

# %%
pip install jpholiday
# Out:
# Requirement already satisfied: jpholiday in c:\programdata\anaconda3\lib\site-packages (0.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
X=0.3#正規化個体数
a=2.1#出生率
year=[]
Xn=[]
Xn1=[]

for i in range(1,101):
    year.append(i)
    Xn.append(X)
    Xnext=a*X*(1-X)
    Xn1.append(Xnext)
    X=Xnext
    
plt.figure(figsize=(20, 6))
plt.grid()
plt.plot(Xn)

# %% [markdown]
# (2)

# %%
plt.figure(figsize=(6, 6))
plt.grid() 
plt.scatter(Xn,Xn1)

# %% [markdown]
# (3)

# %%
Xn=[]
Xn1=[]
def func(a):
    X=0.3#正規化個体数
    for i in range(1,201):
        Xn.append(X)
        Xnext=a*X*(1-X)
        Xn1.append(Xnext)
        X=Xnext
    return Xn1[-10:]

# %%
X=[]
alpha=[]
for a in np.arange(2,5,0.001):
    X.append(func(a))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: overflow encountered in double_scalars
#   import sys

# %%
plt.plot(X)
# Out:
# [<matplotlib.lines.Line2D at 0x27c93daa0b8>,
#  <matplotlib.lines.Line2D at 0x27c93daac18>,
#  <matplotlib.lines.Line2D at 0x27c93daab70>,
#  <matplotlib.lines.Line2D at 0x27c93daa828>,
#  <matplotlib.lines.Line2D at 0x27c93daa898>,
#  <matplotlib.lines.Line2D at 0x27c93daa1d0>,
#  <matplotlib.lines.Line2D at 0x27c93daa6d8>,
#  <matplotlib.lines.Line2D at 0x27c93d83da0>,
#  <matplotlib.lines.Line2D at 0x27c93d83160>,
#  <matplotlib.lines.Line2D at 0x27c93d833c8>]
